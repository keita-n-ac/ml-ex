# %% [markdown]
# ### 2重ループ
# - 繰り返し処理の中に，繰り返し処理を記述することで，より複雑なプログラムを書くことが出来る
# - 2重ループの場合，内側にある繰り返し処理を，外側にあるループで設定した繰り返しで実行する

# %%
# 例: 2重ループで模様作成
# インデント位置に注意すること
for i in range(7):
    for j in range(5):
        print('■', end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# 縦7，横5のタイル出力となる
# Out:
# ■■■■■
# ■■■■■
# ■■■■■
# ■■■■■
# ■■■■■
# ■■■■■
# ■■■■■

# %% [markdown]
# ### 演習A
# - 上のサンプルプログラムを参考に以下のプログラムを実装してください
#
# 1.
# ```
# ○○○○○○
# ○○○○○○
# ○○○○○○
# ○○○○○○
# ```
#
# 2.
# ```
# 01234
# 01234
# 01234
# 01234
# ```
#
# 3.
# ```
# 00000000
# 11111111
# 22222222
# 33333333
# 44444444
# ```

# %%
# 解答例1
for i in range(4):
    for j in range(6):
        print('○', end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# Out:
# ○○○○○○
# ○○○○○○
# ○○○○○○
# ○○○○○○

# %%
# 解答例2
for i in range(4):
    for j in range(5):
        print(j, end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# Out:
# 01234
# 01234
# 01234
# 01234

# %%
# 解答例3
for i in range(5):
    for j in range(8):
        print(i, end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# Out:
# 00000000
# 11111111
# 22222222
# 33333333
# 44444444

# %% [markdown]
# ### 応用: 2重ループ
# - 変数を使用した繰り返し処理を行うことで，さらに複雑な処理を行うことができる

# %%
# 例: 2重ループで階段を生成する
# インデント位置に注意すること
for i in range(10):
    for j in range(i + 1): # 変数iを使って，繰り返しを制御する
        print('■', end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# 縦7，横5のタイル出力となる
# Out:
# ■
# ■■
# ■■■
# ■■■■
# ■■■■■
# ■■■■■■
# ■■■■■■■
# ■■■■■■■■
# ■■■■■■■■■
# ■■■■■■■■■■

# %% [markdown]
# ### 演習B
# - 上のサンプルプログラムを参考に以下のプログラムを実装してください
#
# 1.
# ```
# 0
# 01
# 012
# 0123
# 01234
# 012345
# 0123456
# 01234567
# 012345678
# 0123456789
# ```
#
# 2.
# ```
# 0
# 11
# 222
# 3333
# 44444
# 555555
# 6666666
# 77777777
# 888888888
# 9999999999
# ```
#
#
# 3.
# ```
# ■■■■■■■■■■
# ■■■■■■■■■
# ■■■■■■■■
# ■■■■■■■
# ■■■■■■
# ■■■■■
# ■■■■
# ■■■
# ■■
# ■
# ```
#
# 4.
# ```
#           *
#          **
#         ***
#        ****
#       *****
#      ******
#     *******
#    ********
#   *********
#  **********
# ```

# %%
# 解答例1
for i in range(10):
    for j in range(i + 1): # 変数iを使って，繰り返しを制御する
        print(j, end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# Out:
# 0
# 01
# 012
# 0123
# 01234
# 012345
# 0123456
# 01234567
# 012345678
# 0123456789

# %%
# 解答例2
for i in range(10):
    for j in range(i + 1): # 変数iを使って，繰り返しを制御する
        print(i, end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# Out:
# 0
# 11
# 222
# 3333
# 44444
# 555555
# 6666666
# 77777777
# 888888888
# 9999999999

# %%
# 解答例3
for i in range(10, 0, -1):
    for j in range(i): # 変数iを使って，繰り返しを制御する
        print('■', end='') # jループの処理（改行しない）
    print() # iループの処理（改行する）
# Out:
# ■■■■■■■■■■
# ■■■■■■■■■
# ■■■■■■■■
# ■■■■■■■
# ■■■■■■
# ■■■■■
# ■■■■
# ■■■
# ■■
# ■

# %%
# 解答例4（これも二重ループの1種です）
for i in range(10):
    for j in range(10-i):
        print(' ', end='') # jループの処理（改行しない）
    for k in range(i+1):
        print('*', end='') # kループの処理（改行しない）
    print() # iループの処理（改行する）
# Out:
#           *
#          **
#         ***
#        ****
#       *****
#      ******
#     *******
#    ********
#   *********
#  **********

# %% [markdown]
# ### 応用: 2重ループ
# - 2重ループの中に選択処理を書くことで，より複雑な処理を行うことができる

# %%
# サンプルプログラム: 横縞模様出力
for i in range(15):
    for j in range(20):
        if i % 2 == 0:
            print('■', end='') # jループの処理（改行しない）
        else:
            print('□', end='') # jループの処理（改行しない）
    print('') # iループの処理（改行する）
# Out:
# ■■■■■■■■■■■■■■■■■■■■
# □□□□□□□□□□□□□□□□□□□□
# ■■■■■■■■■■■■■■■■■■■■
# □□□□□□□□□□□□□□□□□□□□
# ■■■■■■■■■■■■■■■■■■■■
# □□□□□□□□□□□□□□□□□□□□
# ■■■■■■■■■■■■■■■■■■■■
# □□□□□□□□□□□□□□□□□□□□
# ■■■■■■■■■■■■■■■■■■■■
# □□□□□□□□□□□□□□□□□□□□
# ■■■■■■■■■■■■■■■■■■■■
# □□□□□□□□□□□□□□□□□□□□
# ■■■■■■■■■■■■■■■■■■■■
# □□□□□□□□□□□□□□□□□□□□
# ■■■■■■■■■■■■■■■■■■■■

# %% [markdown]
# ### 演習C
# - 上のサンプルプログラムを参考に以下のプログラムを実装してください
#
# 1. 縦縞模様
# ```
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ```
#
# 2. 市松模様
# ```
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■
# ```

# %%
# 解答例1
for i in range(10):
    for j in range(10):
        if j % 2 == 0:
            print('■', end='') # jループの処理（改行しない）
        else:
            print('□', end='') # jループの処理（改行しない）
    print('') # iループの処理（改行する）
# Out:
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□
# ■□■□■□■□■□

# %%
# 解答例2
for i in range(10):
    for j in range(10):
        if (i + j) % 2 == 0:
            print('■', end='') # jループの処理（改行しない）
        else:
            print('□', end='') # jループの処理（改行しない）
    print('') # iループの処理（改行する）
# Out:
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■
# ■□■□■□■□■□
# □■□■□■□■□■

# %% [markdown]
# ### 演習1
# - 以下の出力を行うプログラムを作成しなさい
# ```
# ```
#
# - 段数を入力して，以下の入力した階段の出力を行うプログラムを作成しなさい
# ```
# ```

# %% [markdown]
# ### 演習2
# - 以下の出力を行うプログラムを作成しなさい
# ```
# ```
#
# - 段数を入力して，以下の入力した階段の出力を行うプログラムを作成しなさい
# ```
# ```
