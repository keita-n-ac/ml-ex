# %% [markdown]
# 1. 2つの整数を読み込んで，その和，差，積，商を出力するプログラムを作成しなさい．

# %%
num1 = int(input('1つ目の整数を入力してください'))
num2 = int(input('2つ目の整数を入力してください'))

print(num1, 'と', num2, 'の和は', num1 + num2, 'です')
print(num1, 'と', num2, 'の差は', num1 - num2, 'です')
print(num1, 'と', num2, 'の積は', num1 * num2, 'です')
print(num1, 'と', num2, 'の商は', num1 / num2, 'です')
# Out:
# 1つ目の整数を入力してください 12
# 2つ目の整数を入力してください 5
# 12 と 5 の和は 17 です
# 12 と 5 の差は 7 です
# 12 と 5 の積は 60 です
# 12 と 5 の商は 2.4 です

# %% [markdown]
# 2. 正の整数を入力し，接尾辞「-st」，「-nd」，「-rd」，「-th」をつけ，英語の序数として出力するプログラムを作成しなさい．

# %%
num = int(input('正の整数を入力してください'))

if num >= 10 and num // 10 == 1:
    print(num, 'th')
elif num % 10 == 1:
    print(num, 'st')
elif num % 10 == 2:
    print(num, 'nd')
elif num % 10 == 3:
    print(num, 'rd')
else:
    print(num, 'th')
# Out:
# 正の整数を入力してください 9
# 9 th

# %% [markdown]
# 3. 1から100まで順番に数を1行ずつ出力していく．ただし，その数が3で割り切れる または 3が含まれている場合，数字の代わりに Foon を出力するプログラムを作成しなさい．

# %%
for i in range(1, 101):
    if i % 3 == 0 or i // 10 == 3 or i % 10 == 3:
        print('Foon')
    else:
        print(i)
# Out:
# 1
# 2
# Foon
# 4
# 5
# Foon
# 7
# 8
# Foon
# 10
# 11
# Foon
# Foon
# 14
# Foon
# 16
# 17
# Foon
# 19
# 20
# Foon
# 22
# Foon
# Foon
# 25
# 26
# Foon
# 28
# 29
# Foon
# Foon
# Foon
# Foon
# Foon
# Foon
# Foon
# Foon
# Foon
# Foon
# 40
# 41
# Foon
# Foon
# 44
# Foon
# 46
# 47
# Foon
# 49
# 50
# Foon
# 52
# Foon
# Foon
# 55
# 56
# Foon
# 58
# 59
# Foon
# 61
# 62
# Foon
# 64
# 65
# Foon
# 67
# 68
# Foon
# 70
# 71
# Foon
# Foon
# 74
# Foon
# 76
# 77
# Foon
# 79
# 80
# Foon
# 82
# Foon
# Foon
# 85
# 86
# Foon
# 88
# 89
# Foon
# 91
# 92
# Foon
# 94
# 95
# Foon
# 97
# 98
# Foon
# 100

# %% [markdown]
# 4. 段数を入力して，以下の入力した階段の出力を行うプログラムを作成しなさい（2重ループを利用すること）

# %%
n = int(input('段数を入力してください'))
for i in range(n):
    for j in range(n - i - 1):
        print('  ', end='')
    for k in range(2 * i + 1):
        print('**', end='')
    print()
# Out:
# 段数を入力してください 15
#                             **
#                           ******
#                         **********
#                       **************
#                     ******************
#                   **********************
#                 **************************
#               ******************************
#             **********************************
#           **************************************
#         ******************************************
#       **********************************************
#     **************************************************
#   ******************************************************
# **********************************************************
