# %% [markdown]
# # 2023年 機械学習レポート 2回目 (締め切り: 2023/12/14)
# - 以下の問題に示すプログラムを作成しなさい（合計4問）
# - 各問を満たすプログラムをwordに貼り付けて，提出すること
# ####  問題1
#   - データ [3, 5, 4, 4, 4, 6, 3, 4, 5, 6, 1, 5, 4, 4, 4, 1, 5, 5, 6, 3, 1, 2, 3, 6, 2, 3, 5, 2, 6, 5] における，合計値，平均値，分散値，標準偏差値を求めなさい
#     - 標準偏差値は分散値の平方根である
# #### 問題2
#   - コレクションを適切に使用して，1から1000までの整数の中で，『2でも3でも5でも7でも割り切れない数』のコレクションを作成しなさい
# #### 問題3
#   - 以下の説明に従って，題意を満たすヒストグラムを作成しなさい
#     - np.random.randint(a, b) を利用することで，一様なa以上，b未満の整数乱数を作成できる

# %%
# サンプルプログラム
import numpy as np

for i in range(10):
    print(np.random.randint(1, 7))
# Out:
# 2
# 3
# 1
# 6
# 2
# 4
# 2
# 5
# 1
# 2

# %% [markdown]
# - これを利用して，0以上2未満の整数乱数を生成することで，コイン投げのシミュレーションプログラムを作成できる
#   - 1を表，0を裏として扱う
# - この考え方に基づいて，n回のコイン投げシミュレーションを行うことができる
# - 100回のコイン投げシミュレーションを1000回行い，横軸を『表が出た回数』，縦軸を『1000回中に起こった回数』となるようなヒストグラムを作成しなさい

# %% [markdown]
# #### 問題4
# - 以下の説明に従って，題意を満たすヒストグラムを作成しなさい
#   - np.random.rand() を利用することで，0以上1未満の乱数を作成できる

# %%
# サンプルプログラム4-1
import numpy as np

for i in range(10):
    print(np.random.rand())
# Out:
# 0.607003165350193
# 0.6216693868740885
# 0.5741742431794484
# 0.11567778732172063
# 0.04589550913094087
# 0.1051656487906788
# 0.3437453140634482
# 0.6501186421374898
# 0.13816628940157993
# 0.8280284198686343

# %%
# サンプルプログラム4-2
import numpy as np
x = []
for i in range(10):
    x.append(np.random.rand())

print(x)
# Out:
# [0.6277209626014156, 0.07578686218434516, 0.19390427857295145, 0.5901854032666183, 0.1996099935203136, 0.991518315096793, 0.5668978142379921, 0.4543330892590024, 0.6992205135185617, 0.9839594707101704]

# %% [markdown]
# - Step1:
#   - サンプルプログラム4-2を参考にして，データ1（data1）に要素数10000個の乱数を追加することで作成しなさい，データ2（data2）も同様に作成しなさい
# - Step2:
#   - 横軸をデータ1の値，縦軸をデータ2の値として散布図を作成する（ただし，データ2の値がデータ1の値よりも小さい場合とそうでない場合は区別できるように，マーカーと色を変えて表示すること）
